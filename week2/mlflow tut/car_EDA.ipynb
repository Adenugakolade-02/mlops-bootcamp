# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
data = pd.read_csv("CarPrice_Assignment.csv")

# %%
seed = 0

# %%
data.head(10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
# 7       8          1                 audi 5000      gas        std       four
# 8       9          1                 audi 4000      gas      turbo       four
# 9      10          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# #splitting data into train and test set so as to avoid overfitting
# from sklearn.model_selection import train_test_split
# train,test = train_test_split(data, test_size=0.2,random_state=seed)

# %%
# test.to_csv('test.csv',index=False)

# %% [markdown]
# train.reset_index(drop=True)

# %%
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
### grouping into categorical and numerical

numerical_variable = [feature for feature in data.columns if data[feature].dtype!="object"]
categorical_variable = [feature for feature in data.columns if data[feature].dtype=="object"]

# %%
display(data[numerical_variable].head())
print(f'Here is the number of numerical variables', data[numerical_variable].shape[1])
# Out:
#    car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0       1          3       88.6      168.8      64.1       48.8        2548
# 1       2          3       88.6      168.8      64.1       48.8        2548
# 2       3          1       94.5      171.2      65.5       52.4        2823
# 3       4          2       99.8      176.6      66.2       54.3        2337
# 4       5          2       99.4      176.6      66.4       54.3        2824
#
#    enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0         130       3.47    2.68               9.0         111     5000
# 1         130       3.47    2.68               9.0         111     5000
# 2         152       2.68    3.47               9.0         154     5000
# 3         109       3.19    3.40              10.0         102     5500
# 4         136       3.19    3.40               8.0         115     5500
#
#    citympg  highwaympg    price
# 0       21          27  13495.0
# ...

# %%
display(data[categorical_variable].head())
print(f'Here is the number of categorical variables', data[categorical_variable].shape[1])
# Out:
#                     CarName fueltype aspiration doornumber      carbody  \
# 0        alfa-romero giulia      gas        std        two  convertible
# 1       alfa-romero stelvio      gas        std        two  convertible
# 2  alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3               audi 100 ls      gas        std       four        sedan
# 4                audi 100ls      gas        std       four        sedan
#
#   drivewheel enginelocation enginetype cylindernumber fuelsystem
# 0        rwd          front       dohc           four       mpfi
# 1        rwd          front       dohc           four       mpfi
# 2        rwd          front       ohcv            six       mpfi
# 3        fwd          front        ohc           four       mpfi
# 4        4wd          front        ohc           five       mpfi
# Here is the number of categorical variables 10

# %% [markdown]
# ### working with categorical variable first

# %%
data[categorical_variable].describe()
# Out:
#               CarName fueltype aspiration doornumber carbody drivewheel  \
# count             205      205        205        205     205        205
# unique            147        2          2          2       5          3
# top     toyota corona      gas        std       four   sedan        fwd
# freq                6      185        168        115      96        120
#
#        enginelocation enginetype cylindernumber fuelsystem
# count             205        205            205        205
# unique              2          7              7          8
# top             front        ohc           four       mpfi
# freq              202        148            159         94

# %%
##trying feature engineering on the carname
data['name with model'] = data['CarName'].map(lambda x: x.split(maxsplit=1))

# %%
data.tail(5)
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  boreratio  \
# 200   sedan        rwd          front      109.1  ...        mpfi       3.78
# 201   sedan        rwd          front      109.1  ...        mpfi       3.78
# 202   sedan        rwd          front      109.1  ...        mpfi       3.58
# 203   sedan        rwd          front      109.1  ...         idi       3.01
# 204   sedan        rwd          front      109.1  ...        mpfi       3.78
#
# ...

# %%
data['name'] = data['name with model'].apply(lambda x: x[0])

# %%
data['name'].value_counts()
# Out:
# toyota         31
# nissan         17
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# volkswagen      9
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# isuzu           4
# porsche         4
# alfa-romero     3
# chevrolet       3
# jaguar          3
# vw              2
# maxda           2
# renault         2
# toyouta         1
# vokswagen       1
# Nissan          1
# mercury         1
# porcshce        1
# Name: name, dtype: int64

# %%
renaming_map = {'toyouta':'toyota','Nissan':'nissan','vokswagen':'volkswagen','maxda':'mazda','porcshce':'porsche','vw':'volkswagen'}

def rename_cars(data,feature):
    return data[feature].replace(renaming_map)

# %%
data['name'] = rename_cars(data,'name')

# %%
data['name'].value_counts()
# Out:
# toyota         32
# nissan         18
# mazda          17
# mitsubishi     13
# honda          13
# volkswagen     12
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# porsche         5
# isuzu           4
# jaguar          3
# chevrolet       3
# alfa-romero     3
# renault         2
# mercury         1
# Name: name, dtype: int64

# %%
def is_custom(spec_list):
    for items in spec_list.split():
        if items.lower() == "custom":
            return 1
            break
    else:
        return 0

# %%
data['is_custom_made'] = data['name with model'].apply(lambda x: is_custom(x[-1]))

# %%
drop_item = ['car_ID','name with model','CarName']
data.drop(drop_item,axis=1,inplace=True)

# %%
data['is_custom_made'].value_counts()
# Out:
# 0    197
# 1      8
# Name: is_custom_made, dtype: int64

# %% [markdown]
# ### Log transforming numerical data

# %%
numerical_variable.remove('car_ID')

# %%
data[numerical_variable].head(10)
# Out:
#    symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          3       88.6      168.8      64.1       48.8        2548
# 1          3       88.6      168.8      64.1       48.8        2548
# 2          1       94.5      171.2      65.5       52.4        2823
# 3          2       99.8      176.6      66.2       54.3        2337
# 4          2       99.4      176.6      66.4       54.3        2824
# 5          2       99.8      177.3      66.3       53.1        2507
# 6          1      105.8      192.7      71.4       55.7        2844
# 7          1      105.8      192.7      71.4       55.7        2954
# 8          1      105.8      192.7      71.4       55.9        3086
# 9          0       99.5      178.2      67.9       52.0        3053
#
#    enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0         130       3.47    2.68               9.0         111     5000
# 1         130       3.47    2.68               9.0         111     5000
# ...

# %%
def plot_numerical_variables(data,numerical_list,target):
    for features in numerical_list:
        sns.scatterplot(x=target,y=features,data=data)
        plt.show()

# %% [markdown]
# The average car will rack up about 20,000 km each year. To figure out if the car you’re looking at has high or low mileage, divide the number on the odometer by the vehicle’s age. A car with high mileage with have more wear and tear on its mechanical components. Find out more about why high mileage matters when buying a used car.

# %% [markdown]
# Highway MPG: the average a car will get while driving on an open stretch of road without stopping or starting, typically at a higher speed.
# City MPG: the score a car will get on average in city conditions, with stopping and starting at lower speeds.

# %% [markdown]
# Compression ratios usually range from 8:1 to 10:1. A higher compression ratio -- say, from 12:1 to 14:1 -- means higher combustion efficiency. Higher compression ratios and combustion efficiency mean more power with less fuel, and fewer exhaust gases.

# %%
plot_numerical_variables(data,numerical_variable,'price')

# %%
def show_distribution(data,numerical_list):
    for items in numerical_list:
        sns.distplot(data[items])
#         plt.xlabel(f'{items}')
#         plt.ylabel('count')
        plt.show()

# %%
data['horsepower'].min()
# Out:
# 48

# %%
show_distribution(data,numerical_variable)
# Out:
# /home/kolade/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/kolade/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
##updating the numerical list so as log transform

numerical_variable
# Out:
# ['symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
log_variables = [
 'wheelbase',
 'carlength',
 'carwidth',
 'carheight',
 'curbweight',
 'enginesize',
 'boreratio',
 'stroke',
 'compressionratio',
 'horsepower',
 'peakrpm',
 'citympg',
 'highwaympg',
 'price']

# %%
#Log transform here
def take_transformation(data,transform_list):
    data = data.copy()
    for item in transform_list:
        data[item] = np.log(data[item])
    return data

# %%
data = take_transformation(data,log_variables)

# %%
show_distribution(data,numerical_variable)
# Out:
# /home/kolade/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/kolade/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Encoding categorical variables

# %%
###updating the categorial variables
categorical_variable = [feature for feature in data.columns if data[feature].dtype=="object"]

# %%
def plot_categorical_variable(data,categorical_features,target):
    for features in categorical_features:
        sns.boxplot(x=features,y=target,data=data)
        plt.show()

# %%
plot_categorical_variable(data, categorical_variable,'price')

# %%
def encode_categorical_variables(data,cat_variables,target):
    for features in cat_variables:
#     cat_map = {}
        encoded = data.groupby([features])[target].mean().sort_values().index
        cat_map = {k:i for i,k in enumerate(encoded)}
        data[features] = data[features].map(cat_map)

# %%
encode_categorical_variables(data,categorical_variable,'price')

# %%
def plot_categorical_variable(data,categorical_features,target):
    for features in categorical_features:
        sns.barplot(x=features,y=target,data=data)
        plt.show()

# %%
plot_categorical_variable(data, categorical_variable,'price')

# %%
data.head()
# Out:
#    symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0          3         0           0           0        4           2
# 1          3         0           0           0        4           2
# 2          1         0           0           0        0           2
# 3          2         0           0           1        2           0
# 4          2         0           0           1        2           1
#
#    enginelocation  wheelbase  carlength  carwidth  ...  boreratio    stroke  \
# 0               0   4.484132   5.128715  4.160444  ...   1.244155  0.985817
# 1               0   4.484132   5.128715  4.160444  ...   1.244155  0.985817
# 2               0   4.548600   5.142832  4.182050  ...   0.985817  1.244155
# 3               0   4.603168   5.173887  4.192680  ...   1.160021  1.223775
# 4               0   4.599152   5.173887  4.195697  ...   1.160021  1.223775
#
#    compressionratio  horsepower   peakrpm   citympg  highwaympg     price  \
# ...

# %%
features = data.columns.tolist()
features.remove('price')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(data[features])
data[features] = scaler.transform(data[features])

# %%
data.head()
# Out:
#    symboling  fueltype  aspiration  doornumber   carbody  drivewheel  \
# 0   1.743470 -0.328798   -0.469295   -1.130388  2.531635    1.273262
# 1   1.743470 -0.328798   -0.469295   -1.130388  2.531635    1.273262
# 2   0.133509 -0.328798   -0.469295   -1.130388 -1.208799    1.273262
# 3   0.938490 -0.328798   -0.469295    0.884652  0.661418   -0.823274
# 4   0.938490 -0.328798   -0.469295    0.884652  0.661418    0.224994
#
#    enginelocation  wheelbase  carlength  carwidth  ...  boreratio    stroke  \
# 0       -0.121867  -1.802494  -0.397523 -0.851793  ...   0.546398 -1.867342
# 1       -0.121867  -1.802494  -0.397523 -0.851793  ...   0.546398 -1.867342
# 2       -0.121867  -0.713860  -0.197972 -0.177535  ...  -2.620744  0.677603
# 3       -0.121867   0.207605   0.240977  0.154209  ...  -0.485055  0.476844
# 4       -0.121867   0.139788   0.240977  0.248349  ...  -0.485055  0.476844
#
#    compressionratio  horsepower   peakrpm   citympg  highwaympg     price  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train,test,y_train,y_test = train_test_split(data[features],data['price'])

# %% [markdown]
# ### working with more understanding from mlflow

# %% [markdown]
# #### Importing neccessary libraries

# %%
import mlflow

# %%
### creating a new experiment for all our runs
mlflow.create_experiment("teaching_mlflow")

# %%
mlflow.set_experiment("teaching_mlflow")
# Out:
# <Experiment: artifact_location='file:///mnt/c/projects/notebooks/week2/mlflow%20tut/mlruns/2', experiment_id='2', lifecycle_stage='active', name='teaching_mlflow', tags={}>

# %%
### importing the evaluation metrics that will be used
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

# %%
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor

# %%
##creating evaluation metrics for our model

def eval_metrics(actual, pred):
        rmse = np.sqrt(mean_squared_error(actual, pred))
        mae = mean_absolute_error(actual, pred)
        r2 = r2_score(actual, pred)
        return rmse, mae, r2

# %%
###creating a simple run

with mlflow.start_run():
    model = ElasticNet(alpha=0.01,l1_ratio=0.01, random_state=42)
    model.fit(train[features],y_train)
    y_pred = model.predict(test[features])
    rmse, mae, r2 = eval_metrics(y_test, y_pred)
    
    ##logging prameters manually
    
    mlflow.set_tag("model","ElasticNet")
    
    mlflow.log_param('alpha',0.01)
    mlflow.log_param('l1_ratio',0.01)
    mlflow.log_metric("rmse", rmse)
    mlflow.log_metric("r2", r2)
    mlflow.log_metric("mae", mae)
    mlflow.sklearn.log_model(model,"model")
# Out:
# /home/kolade/anaconda3/lib/python3.9/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %%
###creating random hyperparameters for the model we will be  checking 10 random parameters for
import random


for index in range(1,5):
    alpha=random.randint(1,10)/10
    l1 = random.randint(1,10)/10
    state = 42
    model = ElasticNet(alpha=alpha, l1_ratio=l1, random_state=state)
    model.fit(train[features],y_train)
    
    #making prediction
    y_pred = model.predict(test[features])
    rmse, mae, r2 = eval_metrics(y_test, y_pred)
    
#     run_name = f"run_{index}"
    
    with mlflow.start_run():
        
        mlflow.set_tag("model","ElasticNet")
        
        mlflow.log_param("alpha", alpha)
        mlflow.log_param("l1_ratio", l1)
        mlflow.log_metric("rmse", rmse)
        mlflow.log_metric("r2", r2)
        mlflow.log_metric("mae", mae)
        mlflow.sklearn.log_model(model, "model")

# %%
sklearn.__version__

# %%
#obtaining model with lowest r2_score

from mlflow.tracking import MlflowClient

client = MlflowClient()

ex_id = client.get_experiment_by_name(experiment_name).experiment_id

runs_info = client.list_run_infos(ex_id)
all_runs = [run.run_id for run in runs_info]
all_param = [client.get_run(run).data.params for run in all_runs]

alpha_params = [x.get('alpha') for x in all_param]
rmse_score = [client.get_run(run).data.metrics.get('rmse') for run in all_runs]

# %%
compare_alpha = pd.DataFrame({"Run_id":all_runs,"alpha":alpha_params,"rmse_score":rmse_score})

# %%
compare_alpha

# %%
best_run_id = compare_alpha.sort_values("rmse_score").iloc[0]["Run_id"]

# %%
best_model_path = client.download_artifacts(best_run_id,"model")

# %%
best_model_path

# %%
best_model = mlflow.sklearn.load_model(best_model_path)

# %%
best_model

# %%
from sklearn.linear_model import LinearRegression
class Model:
    linear_model = LinearRegression()
    def __init__(self,data,features,target,trained_model=None):
        self.data = data
        self.features = features
        self.target = target
        self.trained_model = self.trained_model
    
    def train(self):
        self.trained_model = self.linear_model.fit(self.data[self.features],self.data[self.target])
    de

# %%
from sklearn.preprocessing import StandardScaler
class ScaleData:
    scaler = StandardScaler()
    def __init__(self,data,variables):
        self.data = data
        self.variables = variables
    
    def fit_transform(self):
        self.scaler.fit(self.data[self.variables])
        return self.scaler.transform(self.data[self.variables])
    
    def tranform(self,test_data,test_variables):
        return self.scaler.transform(test_data[test_variables])

# %%
from sklearn.preprocessing import StandardScaler
class ScaleData:
    scaler = StandardScaler()
    def __init__(self,data,variables):
        self.data = data
        self.variables = variables
    
    def fit_transform(self):
        self.scaler.fit(self.data[self.variables])
        return self.scaler.transform(self.data[self.variables])
    
    def tranform(self,test_data,test_variables):
        return self.scaler.transform(test_data[test_variables])

# %%
    def train(self):
        self.forest = self.intialization.fit(self.X_train, self.y_train)
        self.prediction = self.forest.predict(X_test)

# %%
##fit the model here

# %%
##create model pipelines here
